# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json("recipesInstructions2.json")

# %%
df
# Out:
#        calories                                         categories  \
# 0         426.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1         403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 10        256.0  [Milk/Cream, Dairy, Side, Thanksgiving, Rosema...
# 100       285.0  [Soup/Stew, Tomato, No-Cook, Shrimp, Cucumber,...
# 1000        NaN  [Chicken, Fruit, Potato, Bake, Apple, Pea, Car...
# 10000     166.0  [Herb, Rice, Side, Sauté, Quick & Easy, Mother...
# 10001     489.0  [Cake, Rum, Fruit, Brunch, Dessert, Bake, Rais...
# 10002     178.0  [Garlic, Side, Stir-Fry, Vegetarian, Barley, P...
# 10003     481.0  [Cook Like a Diner, Breakfast, Brunch, Bread, ...
# 10004     221.0  [Condiment/Spread, Food Processor, Fish, Garli...
# 10005    1135.0  [Sandwich, Shellfish, Tomato, Bacon, Crab, Sum...
# 10006     387.0  [Dairy, Pork, Potato, Vegetable, Marinate, Fou...
# 10007     586.0  [Sandwich, Fish, Tomato, Broil, Marinate, Picn...
# ...

# %% [markdown]
# ## Separamos en el dataframe
